# %%
import json

# Replace 'your_file.json' with your JSON file's name
with open('../data/news_data.json', 'r') as file:
    data = json.load(file)

# %%
for i, v in data.items():
    print(v['data'])
# Out:
# {'sentiment': '', 'sentiment_token': 0, 'data': "Meta, formerly known as Facebook, has issued new guidelines for its return-to-office policy, requiring employees to be in their assigned offices most of the week. Attendance will be monitored and tracked, and those who do not comply may face termination or negative performance reviews. The company's CEO, Mark Zuckerberg, has shifted his stance on remote work and is now implementing a more aggressive return-to-office mandate. The new policy is similar to Amazon's and Google's, both of which require employees to work in-office at least three days a week.", 'ds_id': "All the rules of Meta's new aggressive RTO mandate@Business Insider@META", 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-18T21:54:15.999516+00:00', 'num_of_tokens': 1199}
# {'data': 'The ISO 45 SMG has had a significant impact on the meta in Warzone 2 Season 4 and remains a popular weapon in Season 5. The gun is designed for aggressive playstyles and putting pressure on enemies. The recommended loadout includes attachments like the Spiral V3.5 Flash Hider, 7" EX Raptor V2 barrel, A30 Stout rear grip, and Demo Fade Tac stock. Recommended perks include Overkill, Bomb Squad, Fast Hands, and Ghost. The ISO 45 can be unlocked by getting 45 Operator kills without taking any damage using SMGs. An alternative option is the Lachamnn Sub.', 'ds_id': 'Best ISO 45 Warzone 2 loadout: Attachments, class & perks@GGRecon@META', 'timestamp': '2023-08-19T03:13:08.576813+00:00', 'num_of_tokens': 1038, 'model_name': 'gpt-3.5-turbo'}
# {'data': 'The best Warzone 2 weapons in the current meta, based on popularity and data from WZRanked, include the Kastov 762, Cronen Squall, ISO 45, Lachmann Sub, and TAQ-V. The TAQ-V Battle Rifle is considered the best weapon with a 15.7% pick rate due to its high damage, effectiveness at long range, and stability. However, there are other weapons players can experiment with as well. The meta is always changing, so the list may be updated in the future.', 'ds_id': 'Best Warzone 2 weapons: Most popular meta loadouts & tier list (Season 5)@GGRecon@META', 'timestamp': '2023-08-19T03:13:08.576813+00:00', 'num_of_tokens': 1802, 'model_name': 'gpt-3.5-turbo'}
# {'sentiment': 5, 'sentiment_token': 122, 'data': 'The legal disclaimer states that MENAFN provides information without warranty and does not take responsibility for the accuracy, content, legality, or reliability of the article. Complaints or copyright issues should be directed to the article provider.', 'ds_id': "Canada Demands Meta To Lift 'Reckless' Ban On News To Allow Wildfires Information To Be Shared@menafn@META", 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T03:34:28.446753+00:00', 'num_of_tokens': 142}
# {'sentiment': '6.5', 'sentiment_token': 478, 'data': "The Canadian government has called for Meta Platforms Inc. to lift its ban on domestic news sharing. The government believes that the ban is hindering the dissemination of crucial information about wildfires. Meta had restricted Canadian users' access to news content in response to a new law requiring internet giants to compensate for news articles. The dispute highlights the potential public safety risks associated with news bans.", 'ds_id': 'Canada Urges Meta To Lift News Ban Amid Wildfire Crisis  Alphabet (NASDAQ:GOOG), Alphabet (NASDAQ:GOOGL)@Benzinga@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T03:34:28.446753+00:00', 'num_of_tokens': 526}
# {'sentiment': 5, 'sentiment_token': 732, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canada Urges Meta to End Ban on Domestic Online News Amid Wildfires@Tech Times@META', 'data': "The government of Canada has called on Meta to lift its ban on domestic news content in order to ensure the dissemination of accurate information about wildfires in the country's western region. Canadians have expressed frustration about the lack of news links on platforms like Facebook and Instagram, hindering their ability to access vital information. Meta has responded by stating that its Safety Check feature allows people to access updates from reputable sources during emergencies. The ban on news content within Canada was implemented to comply with the country's Online News Act.", 'timestamp': '2023-08-19T04:54:08.455571+00:00', 'num_of_tokens': 801}
# {'sentiment': 4, 'sentiment_token': 1079, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canada asks Meta to reverse news ban as Yellowknife fires burn@Washington Post@META', 'data': 'Canadian authorities have called on Meta to lift its ban on news links that prevents users in Canada from sharing news articles on Facebook and Instagram. The ban, which was put in place in June after Canada passed a law enabling news organizations to negotiate payment for shared articles, has prevented authorities from disseminating vital information on social media platforms during wildfires in the Northwest Territories.', 'timestamp': '2023-08-19T03:54:15.998516+00:00', 'num_of_tokens': 1119}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canada demands Meta lift news ban to allow wildfire info sharing@Reuters@META', 'data': 'The Canadian government has called on Meta to lift its ban on domestic news on its platforms in order to allow people to share information about wildfires. Meta blocked news on Facebook and Instagram in response to a new law requiring internet giants to pay for news articles. Some individuals fleeing wildfires have complained that the ban prevented them from sharing important data. The Canadian government is urging Meta to reinstate news sharing for the safety of Canadians facing the emergency.', 'timestamp': '2023-08-18T19:54:11.911210+00:00', 'num_of_tokens': 503}
# {'sentiment': '', 'sentiment_token': 0, 'data': 'The Canadian government has urged Meta to end its ban on news articles from Canadian sources due to the ongoing surge in wildfires. Transport Minister Pablo Rodriguez criticized Meta\'s ban as "totally unacceptable" and demanded that they allow Canadians access to crucial information about the wildfires. However, Meta stated that they would continue to block news links but users could still access content from official government agencies and emergency services. The ban has faced criticism from Canadian officials, with one member of parliament describing it as "reckless and irresponsible."', 'ds_id': 'Canadian Government Demands Facebook And Instagram Lift Ban On Canadian News Amid Wildfires@Forbes@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-18T19:34:31.974770+00:00', 'num_of_tokens': 797}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Facebook delivers a hardnosed warning to its staff@BusinessLend@META', 'data': 'Meta Platforms, formerly known as Facebook, has announced that employees assigned to an office must appear in person for at least three days a week or risk facing termination. The company believes that requiring employees to be in the office is crucial for boosting collaboration and innovation.\n', 'timestamp': '2023-08-18T22:54:15.999516+00:00', 'num_of_tokens': 840}
# {'sentiment': "Apologies, but your request isn't clear. Please provide an article for the sentiment analysis. Without it, I'm unable to determine a sentiment score.", 'sentiment_token': 228, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Facebook delivers a hardnosed warning to its workers@Capital Journal@META', 'data': 'The article does not provide any information to be summarized.', 'timestamp': '2023-08-18T22:54:15.998516+00:00', 'num_of_tokens': 178}
# {'sentiment': 8, 'sentiment_token': 133, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Facebook delivers a hardnosed warning to its workers@Jackson ProgressArgus@META', 'data': 'METACompany is a proactive organization aiming to reduce cat overpopulation in Butts County by promoting and participating in spaying and neutering. They are focused on finding adoptable cats a suitable home.', 'timestamp': '2023-08-18T23:13:13.503383+00:00', 'num_of_tokens': 148}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Facebook users can now claim settlement money Here's how@CBS News@META", 'data': 'Facebook users in the U.S. who were affected by privacy violations in the last 16 years can claim a portion of a $725m settlement. Users must fill out a claim by the end of August, and the settlement is the result of lawsuits claiming that the company shared personal data with third parties.', 'timestamp': '2023-08-18T20:54:11.910210+00:00', 'num_of_tokens': 1789}
# {'sentiment': 8, 'sentiment_token': 841, 'data': 'The article advises readers to change their Facebook password regularly to enhance account security. It provides step-by-step instructions on how to change the password on both the Facebook website and the mobile app. Additionally, it suggests enabling two-factor authentication for added protection.', 'ds_id': 'How to Change, Reset Your Facebook Password@Business Insider@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T04:54:15.998516+00:00', 'num_of_tokens': 859}
# {'sentiment': 7, 'sentiment_token': 508, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Koo Not Competing Against X, Meta's Threads by Meta; Going After Deeper, Regional Audiences: CoFounder@Gadgets 360@META", 'data': 'The co-founder of Indian social media platform Koo, Aprameya Radhakrishna, stated that Koo is targeting regional audiences with its language-based approach rather than competing directly with platforms like Twitter or Threads. He emphasized the importance of tailoring the platform to comply with local laws and address issues of data misuse and interference in local affairs. Koo has gained popularity as a Twitter rival and has seen success in attracting regional audiences, including Portuguese speakers.', 'timestamp': '2023-08-18T20:54:11.910210+00:00', 'num_of_tokens': 569}
# {'sentiment': '6.5', 'sentiment_token': 390, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Koo does not compete with X, Meta's threads of Meta; Reaching a deeper, regional audience: CoFounders@Worldtimetodays@META", 'data': "Koo, a language-based social media platform, is targeting a regional audience rather than competing with platforms like Twitter and Meta's Threads. Its co-founder, Aprameya Radhakrishna, highlighted Koo's ability to adapt to different countries' laws and its focus on a deeper audience unfamiliar with other platforms. Radhakrishna also mentioned that Portuguese is the third largest language base on Koo.", 'timestamp': '2023-08-18T20:54:11.910210+00:00', 'num_of_tokens': 440}
# {'sentiment': 4.0, 'sentiment_token': 103, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Platforms Inc stock underperforms Friday when compared to competitors@MarketWatch@META', 'data': 'Shares of Meta Platforms Inc. (formerly known as Facebook) experienced a slight decline of 0.71% on Friday, marking the third day in a row of losses for the stock. This occurred despite a positive trading session for the overall stock market.', 'title_correlation': '100', 'timestamp': '2023-12-01T21:30:05.203485+00:00', 'num_of_tokens': 242}
# {'sentiment': '', 'sentiment_token': 0, 'data': "Mark Zuckerberg, CEO of Meta (formerly Facebook), has warned employees that they could face job termination if they fail to comply with the company's three-day-per-week office attendance mandate. Meta is implementing cost-cutting measures, including laying off 21,000 employees, and focusing on enhancing the in-person experience for office workers. Remote workers are advised to visit the office no more than four days every two months unless necessary. This move follows similar strategies by Amazon and other major tech companies.", 'ds_id': 'Meta Warns Employees Could Be Fired If They Ignore New 3DayPerWeek Office Rule@IndiaTimes@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-18T19:54:11.910210+00:00', 'num_of_tokens': 664}
# {'sentiment': '', 'sentiment_token': 0, 'data': 'Meta, the parent company of Facebook, has updated its Return-to-Office (RTO) policy, requiring employees to work from an office at least three days a week. Those who do not comply may face disciplinary action, including the risk of losing their jobs. The policy will take effect in September 2023 and may have mixed impacts on employee morale.', 'ds_id': 'Meta updates its employee RTO policy – requires staff to work from the office@Gizchinacom@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-18T23:54:15.998516+00:00', 'num_of_tokens': 867}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Meta's updated RTO mandate is as strict as Amazon's, with a few unique rules Here are all the key details@Business Insider India@META", 'data': "Facebook's parent company Meta has implemented strict rules for in-office and remote work, requiring employees to be in the office most of the week unless approved for fully remote work. Those who violate the rules risk termination or\xa0negative performance reviews.\n", 'timestamp': '2023-08-18T21:54:11.910210+00:00', 'num_of_tokens': 1091}
# {'sentiment': 6, 'sentiment_token': 789, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Online Book Collection Meta Removed Due to Copyright Issues@Global Village Space@META', 'data': "The takedown of the Books3 database highlights the clash between AI and copyright law as AI models use copyrighted material for training. Meta's reference to using the database raises concerns about big tech companies using copyrighted material without authorization. Clear guidelines and regulations are needed. Potential solutions include partnerships with content creators and the use of synthetic training data. Technical challenges and the need for collaboration between stakeholders must be addressed to strike a balance between AI advancement and copyright protection.", 'timestamp': '2023-08-19T03:13:08.576813+00:00', 'num_of_tokens': 854}
# {'sentiment': 5, 'sentiment_token': 170, 'data': "The paragraph describes different types of cookies used by a website. The first type is necessary cookies which distinguish humans from bots. Functional cookies remember the user's selected language. Performance/Analytical cookies generate statistical data on website usage. Advertising/Marketing cookies collect information on consumer behavior and are sent to Alexa Analytics, an Amazon company.", 'ds_id': 'Ottawa demands Meta end blackout of Canadian news due to wildfire danger@Anadolu Agency@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T04:34:28.446753+00:00', 'num_of_tokens': 211}
# {'sentiment': 4, 'sentiment_token': 250, 'data': "Shares of Meta Platforms Inc, formerly known as Facebook, fell 0.65% to $283.25 on Friday, marking its fourth consecutive day of losses. The stock market had a mixed trading session, with the Dow Jones rising slightly and the NASDAQ falling. Meta's competitors also had mixed performances.", 'ds_id': 'Shares of Meta Platforms Inc Slide 065%@TickerTV News@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-18T21:54:15.999516+00:00', 'num_of_tokens': 281}
# {'sentiment': 4, 'sentiment_token': 203, 'model_name': 'gpt-3.5-turbo', 'ds_id': "1 week left to claim your piece of 725 million Facebook settlement: Here's how@KRZK 1063@META", 'data': "Facebook users are reminded that they have one week left to file a claim in the class-action lawsuit against the social media company. Facebook's parent company, Meta, agreed to pay a settlement to address allegations of allowing personal data to be shared with third parties, including Cambridge Analytica. The deadline to file a claim is August 25, 2023.", 'timestamp': '2023-08-19T05:01:08.455571+00:00', 'num_of_tokens': 243}
# {'sentiment': 8.5, 'sentiment_token': 1134, 'model_name': 'gpt-3.5-turbo', 'ds_id': '2 Unstoppable Stocks That Could Join the 1 Trillion Club@The Motley Fool@META', 'data': "Despite inflationary and recessionary pressures, the U.S. economy remains resilient. The U.S. equity market continues to rally, and investors are growing confident in the Federal Reserve's ability to control inflation without causing a deep recession. Meta Platforms and Tesla, both experiencing significant growth, have the potential to rejoin the trillion-dollar market cap club in the future. Meta Platforms has seen growth in its user base and is focusing on monetizing WhatsApp Business. Tesla's autonomous driving technology and product innovation make it a strong contender for a trillion-dollar market cap. Long-term investors are advised to consider a dollar-cost-averaging strategy with these stocks for potential returns.", 'timestamp': '2023-08-19T12:49:06.869057+00:00', 'num_of_tokens': 1232}
# {'sentiment': 5, 'sentiment_token': 1072, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'AdTheorent (NASDAQ:ADTH) and Meta Platforms (NASDAQ:META) Financial Contrast@Defense World@META', 'data': 'This article compares AdTheorent and Meta Platforms, two business services companies, based on various factors such as analyst recommendations, profitability, risk, valuation, institutional ownership, dividends, and earnings. Meta Platforms has higher revenue and earnings, but AdTheorent is trading at a lower price-to-earnings ratio, making it more affordable. Meta Platforms is more volatile and has higher institutional ownership. Analysts believe AdTheorent has a higher upside potential. Overall, Meta Platforms beats AdTheorent on most factors.', 'timestamp': '2023-08-19T05:39:15.998516+00:00', 'num_of_tokens': 1143}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Andrew Bosworth Sells 8032 Shares of Meta Platforms, Inc (NASDAQ:META) Stock@Defense World@META', 'data': "Andrew Bosworth, CTO of Meta Platforms, has sold 8,032 shares of the company's stock for a total value of $2,459,318.08. Bosworth now owns 11,588 shares in the company, worth $3,548,129.72.", 'timestamp': '2023-08-19T09:49:06.870057+00:00', 'num_of_tokens': 1336}
# {'sentiment': "As there's no article provided, it's impossible to determine a sentiment analysis score.", 'sentiment_token': 85, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'CTV National News: Calls for Meta to unblock news | CTV News@CTV News Vancouver@META', 'data': 'There is no specific article given, so it is not possible to summarize it in 40 words.', 'timestamp': '2023-08-19T18:29:01.950019+00:00', 'num_of_tokens': 47}
# {'sentiment': 4, 'sentiment_token': 423, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canada calls on Meta to lift ban on Instagram and Facebook domestic messages@Worldtimetodays@META', 'data': 'The Canadian government is urging Meta to lift its ban on domestic news on Facebook and Instagram, which was implemented in response to a new law requiring internet giants to pay for news articles. People affected by wildfires in Yellowknife have complained that the ban prevents them from sharing important information about the fires. In response, Meta has enabled the "Safety Check" feature on Facebook to allow users to indicate that they are safe during a crisis. However, the government is requesting that Meta allow the sharing of news articles to ensure the safety of Canadians and provide timely information during emergencies.', 'timestamp': '2023-08-19T16:05:04.662060+00:00', 'num_of_tokens': 504}
# {'sentiment': 3, 'sentiment_token': 103, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Canada demands 'reckless' Meta lifts ban to share wildfire news@Europe@META", 'data': 'The Canadian government has criticized Meta, the owner of Facebook, for blocking news on its platforms, preventing people from sharing information about wildfires. Meta argues that the new law requiring internet giants to pay for news articles is flawed and has activated its "Safety Check" feature instead.', 'timestamp': '2023-08-19T15:29:07.599977+00:00', 'num_of_tokens': 974}
# {'sentiment': 6, 'sentiment_token': 114, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Canada demands Meta lift 'reckless' ban on news to allow fires info to be shared@iHeartRadioca@META", 'data': 'The Canadian government has demanded that Meta lift its ban on domestic news on Facebook and Instagram platforms to allow people to share important information about wildfires in the country. Some individuals affected by the fires have complained that the ban prevented them from sharing crucial data. Meta argues that being forced to pay for shared content is unsustainable for its business.', 'timestamp': '2023-08-19T15:29:04.771812+00:00', 'num_of_tokens': 441}
# {'sentiment': 3, 'sentiment_token': 422, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canada demands Meta to lift ban on local news to allow sharing wildfire information@Pragativadi@META', 'data': "The Canadian government has criticized Meta's ban on sharing news on its platforms, citing concerns about the impact on accessing critical wildfire information. Residents in a northern town affected by wildfires have complained that the ban prevents them from disseminating important fire-related information. Meta argues that users primarily do not use their platform for news and that compensating for shared content would be unsustainable for its business.", 'timestamp': '2023-08-19T05:06:15.998516+00:00', 'num_of_tokens': 466}
# {'sentiment': 3, 'sentiment_token': 105, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Canadians struggle to share wildfire information after Meta news ban@Business Insider@META', 'data': 'Canadian users of Meta platforms are unable to share or view news content due to a ban implemented by the company on August 1. This has hindered the sharing of vital news about ongoing wildfires in western Canada, prompting calls for the ban to be lifted by the Canadian Heritage Minister.\n', 'timestamp': '2023-08-19T19:29:07.599977+00:00', 'num_of_tokens': 662}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Elon Musk’s Latest Antics Have Some Asking: Is He Out of Touch | Mint@Mint@META', 'data': "Elon Musk's recent threats and antics, such as proposing a physical fight with Mark Zuckerberg, have led to concerns that he has lost touch with reality, causing problems for his businesses. Supporters worry that Musk's cult of personality is warping his perspective and hindering his decision-making process. Furthermore, Musk's companies, including Tesla and Meta (formerly Facebook), are currently facing crucial challenges. Tesla's shares have fallen while the company faces investor concerns over price cuts and increased competition. Meta's Chief Executive is trying to attract advertisers back to the platform after many brands fled under Musk's leadership.\n", 'timestamp': '2023-08-19T09:49:04.663061+00:00', 'num_of_tokens': 1468}
# {'sentiment': 5, 'sentiment_token': 115, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Facebook 725 Million Settlement: How to Claim Your Money@Barron's@META", 'data': "Facebook users have until November 23 to opt in to a $725 million class action settlement related to the Cambridge Analytica data scandal. Here's how to participate and claim a share of the settlement.", 'timestamp': '2023-08-19T15:49:02.020467+00:00', 'num_of_tokens': 124}
# {'sentiment': 5, 'sentiment_token': 731, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Facebook delivers a hardnosed warning to its workers@The Daily Courier@META', 'data': 'Meta Platforms, formerly known as Facebook, is requiring employees to return to the office for at least three days a week. This decision comes after the company announced plans to lay off 10,000 workers and marks a shift away from the work-from-home options that became popular during the COVID-19 pandemic.', 'timestamp': '2023-08-19T05:16:08.454570+00:00', 'num_of_tokens': 761}
# {'sentiment': 4, 'sentiment_token': 214, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Federal Minister urges Meta to end 'reckless' news block amid wildfire crises@EverythingGP@META", 'data': "Canada's Heritage Minister, Pascale St-Onge, is urging Meta (formerly known as Facebook) to end its news block and allow people to share news articles on Facebook and Instagram. St-Onge argues that access to news is crucial, especially during the ongoing wildfire crises in British Columbia and the Northwest Territories.", 'timestamp': '2023-08-19T16:34:02.020467+00:00', 'num_of_tokens': 245}
# {'sentiment': 6.5, 'sentiment_token': 120, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Final days to claim onetime 100 direct payment from 725million Facebook settlement – exact steps to a@The US Sun@META', 'data': 'Facebook users have a few days left to claim a one-time $100 direct payment from a $725 million class action lawsuit settlement. The settlement is the result of allegations that Facebook shared user data without permission. Eligible US residents can apply for the settlement by August 25, 2023, and the payout amount will depend on various factors.', 'timestamp': '2023-08-19T22:29:01.949019+00:00', 'num_of_tokens': 597}
# {'sentiment': 4, 'sentiment_token': 818, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'From glow to "nothing" Why did "Threads" fall@Ruetir@META', 'data': 'Threads, the platform launched by Meta (formerly Facebook) as a competitor to Twitter, initially achieved impressive numbers with millions of users signing up. However, within a week of its launch, the platform saw a rapid decline in active users and time spent on the app. The lack of unique features, boring content, and failure to expand to Europe were cited as contributing factors to its collapse. Additionally, legal challenges faced by Meta in the European Union may impact the future of Threads.', 'timestamp': '2023-08-19T05:46:08.454570+00:00', 'num_of_tokens': 882}
# {'sentiment': 7.5, 'sentiment_token': 1797, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Grey Street Capital LLC Acquires New Position in Meta Platforms, Inc (NASDAQ:META)@MarketBeat@META', 'data': "Grey Street Capital has purchased 23,142 shares of Meta Platforms for $4.9m, making the social networking firm its fifth-largest holding. The company accounts for around 3.5% of Grey Street's portfolio. Other investors included Mirae Asset Global Investments, which added more than 249,000 Meta Platforms shares.\n", 'timestamp': '2023-08-19T14:49:06.869057+00:00', 'num_of_tokens': 1831}
# {'sentiment': 8, 'sentiment_token': 408, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Grey Street Capital LLC Acquires New Position in Meta Platforms@TickerTV News@META', 'data': "Grey Street Capital LLC acquired 23,142 shares of Meta Platforms, Inc. in the first quarter, making it their fifth largest holding. Other institutional investors and hedge funds also made moves with regards to their stakes in Meta Platforms. The company's CTO and COO have recently sold shares, and research analysts have given the stock a buy rating. Meta Platforms develops products for social media platforms like Facebook, Instagram, Messenger, and WhatsApp.", 'timestamp': '2023-08-19T14:49:06.869057+00:00', 'num_of_tokens': 465}
# {'sentiment': 5, 'sentiment_token': 136, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Hasbulla Supports Elon Musk’s 44,000,000,000 Investment and Jibes at Mark Zuckerberg: “Threads Is One of…”@The SportsRush@META', 'data': "Elon Musk's Twitter platform, X, and Mark Zuckerberg's Meta, formerly known as Facebook, are engaged in a rivalry over their social media platforms. Hasbulla Magomedov, a Russian social media star, has sided with Musk by mocking Zuckerberg and his platform Thread. Musk and Zuckerberg's feud has escalated to the point where they have agreed to an MMA battle, but the details of the fight have yet to be finalized.", 'timestamp': '2023-08-19T20:29:01.949019+00:00', 'num_of_tokens': 654}
# {'sentiment': 5, 'sentiment_token': 170, 'data': "Canada's Heritage Minister, Pascale St-Onge, has called on Meta (formerly Facebook) to end its ban on Canadian news content on its platforms, stating that it is putting people's lives at risk. The ban was in response to federal legislation requiring tech giants to pay for news content. As wildfires continue to ravage British Columbia and the Northwest Territories, Canadians are unable to access important information on Facebook and Instagram. St-Onge believes that Meta should be acting as a responsible corporate citizen and reversing the ban. However, a spokesperson for Meta argued that Canadians can still access timely information through their platforms.", 'ds_id': 'Heritage Minister says Meta news block endangers lives as Canadians flee wildfires@Yahoo Finance@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T21:29:04.770812+00:00', 'num_of_tokens': 988}
# {'sentiment': 8, 'sentiment_token': 1087, 'data': 'Meta\'s language model LLaMA, which leaked earlier this year, has become popular among developers and researchers in the open-source community. The model has made significant breakthroughs, and Meta has released an updated version, LLaMA 2, which overcomes the tradeoff between safety and helpfulness. While not fully "open source," LLaMA 2 is an "open innovation" that has gained support from major partners like IBM and Amazon. Open-source models like LLaMA are becoming the preferred choice for corporates and lone coders.', 'ds_id': 'How Meta Broke the Barriers To Entry With LLaMA 2@Analytics India Magazine@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T05:36:08.454570+00:00', 'num_of_tokens': 1167}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Javier Olivan Sells 7636 Shares of Meta Platforms, Inc (NASDAQ:META) Stock@Defense World@META', 'data': "Meta Platforms COO Javier Olivan has sold 7,636 shares of the company's stock in a transaction worth $2.34m. Olivan also sold 4,277 shares on Thursday, August 17th, for a total value of $1.25m.", 'timestamp': '2023-08-19T09:49:06.870057+00:00', 'num_of_tokens': 1348}
# {'sentiment': 9, 'sentiment_token': 178, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Latest Feature From WhatsApp Will Enable Sharing HD Images Up To 4160x2080 Resolution@Indiacom@META', 'data': "WhatsApp is introducing a new feature that allows users to share high-definition (HD) images up to 4160×2080 pixel resolution. This feature, announced by Meta CEO Mark Zuckerberg, allows users to choose between HD and standard quality (SD) images when sharing photos. The HD images will have an 'HD' watermark below them, and users will also have the option to share images in standard quality up to 1600×800 pixel resolution. In addition to this update, WhatsApp recently launched a screen lock feature for enhanced privacy on WhatsApp Web, and it has also introduced a new chat share sheet and redesigned emoji panel for beta users.", 'timestamp': '2023-08-19T17:29:07.599977+00:00', 'num_of_tokens': 869}
# {'sentiment': 7.5, 'sentiment_token': 1717, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Loop Capital Raises Meta Platforms (NASDAQ:META) Price Target to 37500@MarketBeat@META', 'data': 'Loop Capital has raised its price target for Meta Platforms from $365 to $375 per share, indicating a potential upside of 33.35% from the company\'s previous close. Other research analysts have also given positive ratings, with Meta Platforms currently having a consensus rating of "Moderate Buy".', 'timestamp': '2023-08-19T14:49:06.869057+00:00', 'num_of_tokens': 1743}
# {'sentiment': 7.5, 'sentiment_token': 665, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Data Limited (AIU) Traded Shares Reflect Intraday Gain of 1960%@Clayton County Register @META', 'data': "Meta Data Limited (AIU) traded 1.05 million shares and closed at $1.23, representing a 19.60% intraday gain. The stock has seen a 43.09% gain since reaching a 52-week low of $0.70. Analysts have given it a consensus Hold recommendation. The company's earnings per share for the current quarter are expected to be $0. The consensus price target is $301.85, implying a potential increase of 99.59% from the current value. The company is expected to see a revenue increase of 41,605.60% compared to the previous year. The next quarterly earnings report is set to be released in September.", 'timestamp': '2023-08-19T16:28:02.020467+00:00', 'num_of_tokens': 777}
# {'sentiment': 7.5, 'sentiment_token': 1329, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Platforms Emerges as a Promising Choice Amid AI Evolution@The Hindu BusinessLine@META', 'data': 'The article discusses the performance and prospects of the "Magnificent Seven" stocks, including Apple, Amazon, Alphabet, Microsoft, Meta Platforms, Nvidia, and Tesla. These companies are expected to benefit from the rise of Generative AI and have strong positions in technology, talent, and cash reserves. The article focuses on Meta Platforms, highlighting its recent turnaround and recommending investors accumulate the stock on dips. The risks include an economic slowdown and market volatility. Overall, the long-term outlook for these stocks is positive due to the growth of Generative AI.', 'timestamp': '2023-08-19T14:49:06.869057+00:00', 'num_of_tokens': 1405}
# {'sentiment': 8.5, 'sentiment_token': 369, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Portal Go: The Portable Video Calling Solution for a Closer Connection@Global Village Space@META', 'data': 'The Meta Portal Go is a portable smart video calling device that allows users to stay connected with loved ones. It has a built-in battery and carry handle, making it convenient to move from room to room. It can be used with popular apps like Messenger and WhatsApp, and has features such as a Smart Camera and high fidelity audio. Privacy settings allow users to disable the camera and microphone, and calls are end-to-end encrypted. The device requires AC power for charging and voice command availability may vary. Some features may require a Facebook account and the Meta Portal mobile app. Employer restrictions on third-party video-calling apps may apply.', 'timestamp': '2023-08-19T16:38:02.019466+00:00', 'num_of_tokens': 461}
# {'sentiment': 8.5, 'sentiment_token': 440, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Quest 3: Bringing Advanced Mixed Reality to Consumers@Game Is Hard@META', 'data': 'Meta Quest 3 is set to bring advanced mixed reality technology to consumers, offering new and exciting experiences. Mixed reality blends digital elements with the physical environment, enhancing everyday life rather than replacing it. Meta Quest 3 aims to address limitations in spatial understanding and object recognition, allowing for more immersive experiences. The affordability compared to other headsets could drive innovation in the field. Mixed reality offers limitless possibilities, incorporating real-world elements for enhanced immersion and interaction.', 'timestamp': '2023-08-19T15:49:02.020467+00:00', 'num_of_tokens': 497}
# {'sentiment': 3, 'sentiment_token': 539, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta to take strict action against employees who refuse to return to office 3 days a week@India Today@META', 'data': "Meta, led by Mark Zuckerberg, has warned employees that failure to spend at least three days in the office each week could result in job loss. The policy is part of Meta's cost-cutting efforts and aims to encourage teamwork and better performance. Remote workers have different requirements.", 'timestamp': '2023-08-19T05:32:08.454570+00:00', 'num_of_tokens': 563}
# {'sentiment': 8, 'sentiment_token': 153, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'MetaFour Pick Up Victory At NXT Live Event@Diva Dirt@META', 'data': 'Meta-Four, a stable consisting of Lash Legend, Jakara Jackson, Oro Mensah, and Noam Darr, emerged victorious at an NXT live event in Citrus Springs, Florida. The event also featured the debut of Jade Gentile in the ring, who teamed up with Lola Vice and Elektra Lopez to defeat Jacy Jayne, Kiana James, and Tiana Caffey. Other results included Gigi Dolin defeating Karmen Petrovic and Dani Palmer defeating Brooklyn Barlow.', 'timestamp': '2023-08-19T23:09:01.949019+00:00', 'num_of_tokens': 334}
# {'sentiment': 5, 'sentiment_token': 145, 'data': "Canadian Heritage Minister Pascale St-Onge is urging Meta, the parent company of Facebook and Instagram, to end its ban on Canadian news content. St-Onge argues that the ban is putting people's lives at risk during the wildfires in British Columbia and the Northwest Territories. Meta implemented the ban in response to federal legislation that would require tech giants to pay for news content on their platforms. St-Onge is calling on Meta to act as a good corporate citizen and reverse the ban.", 'ds_id': 'News blocking by Meta puts lives at risk, says Minister StOnge@The Saxon@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T23:21:04.770812+00:00', 'num_of_tokens': 899}
# {'sentiment': 7, 'sentiment_token': 1295, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Nicholas Clegg Sells 2146 Shares of Meta Platforms, Inc (NASDAQ:META) Stock@Defense World@META', 'data': "An insider at Meta Platforms sold 2,146 shares of the company's stock for a total transaction value of $657,083.74. Following the sale, the insider now owns 12,631 shares in the company.", 'timestamp': '2023-08-19T10:49:06.870057+00:00', 'num_of_tokens': 1310}
# {'sentiment': 8, 'sentiment_token': 122, 'data': "Riot Games is making changes to the League of Legends meta and jungle mechanics. Champions like Kindred, Evelynn, Kain, and Kha’Zix are receiving adjustments to balance gameplay. Epic monster damage reduction near allies will decrease by 15%, and jungle pets' abilities are also being altered. These changes aim to diversify and balance the gameplay.", 'ds_id': 'Riot Games prepares for significant changes in League Of Legends meta after MidSeason Invitational 2023 @CodeList@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T19:29:01.950019+00:00', 'num_of_tokens': 548}
# {'sentiment': '', 'sentiment_token': 0, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Susan J Li Sells 10643 Shares of Meta Platforms, Inc (NASDAQ:META) Stock@Defense World@META', 'data': "Meta Platforms CFO Susan J. Li has sold 10,643 shares of the company's stock, valued at over $3.25m. Following the sale, Li now directly owns 91,617 shares of Meta Platforms stock, worth around $28.05m. The transaction has been disclosed to the Securities & Exchange Commission.", 'timestamp': '2023-08-19T09:49:06.870057+00:00', 'num_of_tokens': 1270}
# {'sentiment': 8, 'sentiment_token': 326, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'WhatsApp now lets you send HD photos@ARY News@META', 'data': 'Meta-owned WhatsApp is rolling out an upgrade that will allow users to share high-definition (HD) photos through the messaging app. The feature, previously in beta testing, will be available worldwide in the coming weeks and includes options for different resolution levels. WhatsApp also plans to support the transfer of HD videos in the future.', 'timestamp': '2023-08-19T05:01:08.455571+00:00', 'num_of_tokens': 358}
# {'sentiment': 8, 'sentiment_token': 468, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'WhatsApp rolling out the feature to share HDquality photos@Gadget Bridge@META', 'data': 'Meta has released a new update for WhatsApp that allows users to send HD-quality images within the app. The feature, previously in a testing phase, is now available for iOS and Android users worldwide. The update includes a new HD button that users can select to send high-quality images, although it requires more data and storage space. Recipients with poor internet connections will still receive a standard version. HD videos are not yet supported, but users can upload videos as documents to avoid compression. The HD photos will be protected by end-to-end encryption.', 'timestamp': '2023-08-19T09:49:06.870057+00:00', 'num_of_tokens': 545}
# {'sentiment': 4, 'sentiment_token': 564, 'data': 'Canadian leaders and news organizations are urging Meta to reverse its ban on sharing news articles on Facebook and Instagram. The ban has hindered access to vital information during the wildfires in the Northwest Territories, prompting frustration among Canadian authorities. Meta argues against revenue-sharing with news publishers, but supporters of regulation believe social media platforms should contribute to the media industry. Meta has previously faced regulatory proposals in Australia and California.', 'ds_id': 'Yellowknife fires continue to rage while Canada appeals to Meta for lifting news ban@VigourTimes@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-19T05:03:08.455571+00:00', 'num_of_tokens': 612}
# {'sentiment': 8.5, 'sentiment_token': 169, 'model_name': 'gpt-3.5-turbo', 'ds_id': '5 Stocks ChatGPT Said Will Make Me Rich in 10 Years@Insider Monkey@META', 'data': "Warren Buffett was one of the first successful hedge fund managers, achieving high returns by investing in the stock market. He charged a fee of 25% on returns exceeding 6%. Despite underperforming the market in 1958, Buffett's investors were satisfied due to his strong performance in 1957. Between 1957 and 1966, Buffett's hedge fund saw annual returns of 23.5%, significantly outperforming the average annual return of the S&P 500 Index. Buffett's strategy involves generating returns in the range of 20% to 30%.", 'timestamp': '2023-08-20T20:32:37.737909+00:00', 'num_of_tokens': 763}
# {'sentiment': 5, 'sentiment_token': 104, 'data': 'The Allstate Corporation cut its holdings in Kilroy Realty Corporation by almost 30% in the first quarter, according to a filing with the Securities and Exchange Commission. Allstate owned 40,723 shares worth $1.32m at the end of the reporting period.\n', 'ds_id': 'Allstate Corp Decreases Stock Holdings in Kilroy Realty Co (NYSE:KRC)@MarketBeat@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-20T17:32:37.738909+00:00', 'num_of_tokens': 1301}
# {'sentiment': 5, 'sentiment_token': 109, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Allstate Corp Decreases Stock Holdings in Safehold Inc (NYSE:SAFE)@MarketBeat@META', 'data': 'Insurance company Allstate Corp. reduced its stake of common stock in Safehold Inc by 57.5% during the first quarter of this year, worth an estimated $1.6m. Safehold offers a new way for real estate owners to unlock the value of the land underneath their buildings.', 'timestamp': '2023-08-20T17:32:37.738909+00:00', 'num_of_tokens': 1390}
# {'sentiment': 4, 'sentiment_token': 116, 'data': "Canadian news publishers are scrambling to find alternative ways to reach audiences after Meta (formerly Facebook) blocked Canadian news links on its platforms in response to Canada's Online News Act, which requires companies to pay media outlets for content. News organizations have asked for an investigation into Meta's decision, but Meta has not indicated an end to the ban.\n", 'ds_id': "Canadian media trained audiences to use Facebook With Meta blocking news, what's next@CBC@META", 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-20T17:32:37.737909+00:00', 'num_of_tokens': 1685}
# {'sentiment': 8, 'sentiment_token': 117, 'data': 'Changing your name on Facebook is a simple process that can be done in the Settings section of the website or mobile app. However, you can only change your name once every 60 days, and there are certain guidelines for what types of names are allowed. Nicknames can be used as long as they are a variation of your actual name.', 'ds_id': 'How to Change Your Name on Facebook@Business Insider@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-20T09:32:40.463694+00:00', 'num_of_tokens': 936}
# {'sentiment': 8, 'sentiment_token': 145, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Instagram to Launch New Voice Notes Feature for Users: Details and Updates@AsumeTech@META', 'data': "Meta, the parent company of Instagram, plans to introduce a voice notes feature on the platform. Users will be able to create and share voice notes, adding a new dimension to communication on Instagram. The feature is still being developed and has not been officially tested yet. In addition to voice notes, Instagram is also exploring a group tagging feature and has recently updated its direct messaging functionality to enhance the user experience. These updates showcase Meta's commitment to innovation and improving user engagement on Instagram.", 'timestamp': '2023-08-20T09:32:40.464694+00:00', 'num_of_tokens': 909}
# {'sentiment': 5, 'sentiment_token': 119, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Javier Olivan Sells 4277 Shares of Meta Platforms, Inc (NASDAQ:META) Stock@Defense World@META', 'data': 'Meta Platforms COO Javier Olivan has sold a total of 12,913 shares of stock in the company. Olivan sold 4,277 shares at an average price of $293 per share and 7,636 shares at an average price of $306.19 per share. This indicates a total value of $12.4m.', 'timestamp': '2023-08-20T11:32:40.463694+00:00', 'num_of_tokens': 1383}
# {'sentiment': 8.5, 'sentiment_token': 92, 'data': 'Loop Capital has raised its target price for Meta Platforms (formerly Facebook) from $365 to $375, with a "buy" rating. The new price represents a potential upside of 32.39%.', 'ds_id': 'Loop Capital Increases Meta Platforms (NASDAQ:META) Price Target to 37500@Defense World@META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-20T06:32:40.464694+00:00', 'num_of_tokens': 1659}
# {'sentiment': 6.5, 'sentiment_token': 124, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Mark Zuckerberg tipped to turn pro and win MMA fight as talks over Elon Musk superfight continue@The US Sun@META', 'data': 'Facebook CEO Mark Zuckerberg is in talks with UFC President Dana White to compete in the organization as a professional MMA fighter. MMA star Mikey Musumeci, who has trained with Zuckerberg, believes he has the potential to win a fight. The proposed super fight between Zuckerberg and Elon Musk has been put on hold, with Zuckerberg saying he wants to focus on competing seriously.', 'timestamp': '2023-08-20T23:32:35.016686+00:00', 'num_of_tokens': 575}
# {'sentiment': 4, 'sentiment_token': 218, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta Agrees to 725 Million Settlement Over Privacy Violations – Meshrepublic@Meshrepublic@META', 'data': 'Meta, formerly known as Facebook, has agreed to a $725 million settlement over allegations of privacy violations related to user data sharing. The settlement stems from multiple lawsuits claiming that Facebook shared user data with third parties without consent. The British consulting firm Cambridge Analytica, known for its involvement in conservative movements, was among the entities accused of accessing this data. Meta maintains its innocence but has accepted the terms of the settlement. The settlement is open to US residents who were Facebook users between May 24, 2007, and December 22, 2022, and claims must be filed by August 25, 2023. Payments will be made through various methods, and the payout amount will vary depending on the number of eligible claimants and their activity on the platform. The settlement highlights the need for accountability and transparency in protecting user data.', 'timestamp': '2023-08-20T23:41:37.737909+00:00', 'num_of_tokens': 946}
# {'sentiment': 8.5, 'sentiment_token': 121, 'data': 'Loop Capital has raised its target price for Meta Platforms from $365.00 to $375.00, with a "buy" rating. Other analysts have also increased their target prices for the social networking company, and Meta Platforms\' stock has a 12-month low of $88.09 and a 12-month high of $326.20.', 'ds_id': 'Meta Platforms Target Price Raised by Loop Capital@Clayton County Register @META', 'model_name': 'gpt-3.5-turbo', 'timestamp': '2023-08-20T07:32:40.464694+00:00', 'num_of_tokens': 561}
# ...
# {'sentiment': 8.5, 'sentiment_token': 219, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta to build general AI for everyone, Zuckerberg says@Verdict@META', 'data': 'Meta is merging its two AI research teams to advance its goal of developing general AI accessible to everyone. CEO Mark Zuckerberg highlighted the need for comprehensive AI, including assistants, business applications, and creator tools. The company plans to acquire 350,000 H100 GPUs from NVIDIA, aiming for 600,000 GPUs by 2024. Zuckerberg emphasized the significant infrastructure being built to support these efforts, positioning Meta competitively against OpenAI and Microsoft in the AI race. Despite the shift towards AI, Zuckerberg sees the metaverse as integral to the future, envisioning smart glasses as a key interface for interacting with AI. GlobalData forecasts the AI market to reach $909 billion by 2030, with GenAI revenues expected to grow from $1.8 billion in 2022 to $33 billion in 2027.', 'title_correlation': '100', 'timestamp': '2024-01-19T14:11:22.562973+00:00', 'num_of_tokens': 807}
# {'sentiment': 8.5, 'sentiment_token': 154, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Meta's AI plans: Zuckerberg lays out 'future roadmap'@YAHOO!News@META", 'data': "Facebook's parent company, Meta, is focusing on developing artificial general intelligence (AGI) that can solve problems without human intervention. CEO Mark Zuckerberg stated that the company's long-term vision is to build and make widely available general intelligence through open-source software. Meta is also purchasing 350,000 graphics cards to power its large language model, Llama 3. Additionally, the company aims to merge its AI research teams and integrate AI into devices like the recently launched Meta Ray-Ban smart glasses.", 'title_correlation': '100', 'timestamp': '2024-01-19T15:00:14.981569+00:00', 'num_of_tokens': 538}
# {'sentiment': 2.0, 'sentiment_token': 107, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Meta, TikTok Can't Escape Suit Over Health Data Tracking@Law360@META", 'data': "A California federal judge denies Meta Platforms Inc. and TikTok Inc.'s request to dismiss a proposed class action lawsuit alleging illegal collection of personal health information from Hey Favor's telemedicine patients. The judge finds insufficient evidence of consent and rejects the argument of untimely filing.", 'title_correlation': '100', 'timestamp': '2024-01-20T03:52:06.242086+00:00', 'num_of_tokens': 315}
# {'sentiment': 5.5, 'sentiment_token': 195, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Metaverse gaming will remain niche but trigger M&A activity in 2024@Verdict@META', 'data': 'The metaverse, touted as the successor to the mobile internet, faced setbacks in 2023 due to waning interest, economic challenges, and immature technologies. In 2024, Apple plans to launch the high-priced Vision Pro AR headset, while Samsung, Google, and Qualcomm are developing a mixed-reality headset. Meta will release the Quest 3 Lite VR headset, targeting mass appeal. Despite these releases, mainstream adoption of metaverse gaming is hindered by the underdeveloped state of augmented and virtual reality technologies. M&A activity in 2024 is expected to focus on acquiring game publishers and 3D game engine providers to enhance content, community, talent, and technologies for immersive experiences.', 'title_correlation': '90', 'timestamp': '2024-01-19T07:44:33.704277+00:00', 'num_of_tokens': 707}
# {'sentiment': 8.0, 'sentiment_token': 157, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Meta’s BillionDollar Bet on Nvidia AI Chips: A Strategic Move for Future Tech@PC Tablet@META', 'data': "Meta Platforms, helmed by CEO Mark Zuckerberg, is set to invest billions of dollars in Nvidia's H100 graphics processing units (GPUs) to advance its artificial intelligence (AI) capabilities. The company aims to acquire 350,000 H100 GPUs by the end of 2024, positioning itself as a major player in the AI field and aligning with Zuckerberg's focus on AI. The investment reflects Meta's commitment to AI research and its intention to compete with other tech giants in the development of artificial general intelligence.", 'title_correlation': '100', 'timestamp': '2024-01-19T20:05:17.178552+00:00', 'num_of_tokens': 518}
# {'sentiment': 8.5, 'sentiment_token': 305, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'S&P 500 Hits AllTime High in Historic Bull Run: Markets Wrap@Swissinfo@META', 'data': 'Wall Street ends the week positively, hitting intraday records amid speculation of Federal Reserve rate cuts in 2024. S&P 500 surpasses 4,800, led by a technology rally fueled by hopes of continued AI market growth. The index erases weekly losses, with semiconductor stocks boosted by Taiwan Semiconductor\'s bullish forecast. The "Magnificent Seven" tech giants drive January gains. Bank of America notes a shift toward tech stocks, and UBS predicts S&P 500 targets of 4,900 and 5,000. The market remains optimistic, with historical data suggesting further gains. Traders focus on central bank officials\' remarks, while economist Mohamed El-Erian cautions against overestimating the pace of rate cuts. Corporate highlights include Apple opening tap-to-pay to rivals, EU likely blocking Amazon\'s iRobot acquisition, and Ford cutting F-150 Lightning production. Other updates include positive results for J.B. Hunt and SLB, while Comerica forecasts a decline in net interest income. Market movements: S&P 500 up 1%, Nasdaq 100 up 1.6%, Dow Jones up 0.9%. Cryptocurrencies see modest gains, and 10-year Treasury yield at 4.16%.', 'title_correlation': '30', 'timestamp': '2024-01-19T19:01:06.855260+00:00', 'num_of_tokens': 1124}
# {'sentiment': 8.5, 'sentiment_token': 153, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'S&P 500 Shatters Records: The TopPerforming Stocks In January 2024@Business Insider@META', 'data': "The S&P 500 has reached a new all-time high at 4,839 points, driven by U.S. tech giants and AI-related stocks. The Federal Reserve's pause in tightening cycles suggests potential interest rate cuts in 2024. Top gainers include NVIDIA, Meta Platforms, and Advanced Micro Devices, with triple-digit percentage gains in 2023. The largest contributors to the index's year-to-date performance include NVIDIA, Microsoft, Meta Platforms, Broadcom, and Advanced Micro Devices.", 'title_correlation': '35', 'timestamp': '2024-01-19T21:17:15.943708+00:00', 'num_of_tokens': 468}
# {'sentiment': 8.0, 'sentiment_token': 225, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'S&P 500 hits alltime high in historic bull run, surpasses 2022 record@Hindustan Times@META', 'data': "Stocks closed at all-time highs on Wall Street, driven by speculation that the Federal Reserve will cut rates this year, boosting Corporate America's outlook. The S&P 500 hit a record, fueled by a rally in technology, particularly in artificial intelligence. The market is optimistic about easing inflation, lower interest rates, and economic growth. Despite potential concerns about concentrated gains in certain stocks, the overall market sentiment remains positive. The S&P 500's recent record-breaking streak suggests the potential for further gains, with historical trends supporting continued upward momentum. However, caution is advised as some warn of a potential pullback, especially in technology stocks, amid high valuations. The market is closely watching central bank officials' remarks regarding potential rate cuts, with differing views on the timing and extent of any policy changes. Economic data resilience and inflation concerns continue to shape market expectations.", 'title_correlation': '70', 'timestamp': '2024-01-20T00:18:24.602375+00:00', 'num_of_tokens': 986}
# {'sentiment': 5.0, 'sentiment_token': 95, 'model_name': 'gpt-3.5-turbo', 'ds_id': "S&P 500 hits alltime high in historic bull run@Crain's Chicago Business@META", 'data': 'In January, key companies like Nvidia, Microsoft, and Meta Platforms, part of the "Magnificent Seven" tech cohort, have experienced notable developments. Further details about these events are not provided in the provided text.', 'title_correlation': '70', 'timestamp': '2024-01-19T17:00:16.745262+00:00', 'num_of_tokens': 227}
# {'sentiment': 7.0, 'sentiment_token': 112, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Sheryl Sandberg, who helped to turn Facebook into digital advertising empire, to leave company board@Bostoncom@META', 'data': "Sheryl Sandberg, former COO of Meta (formerly Facebook), will step down from the company's board. Sandberg, who helped transform Facebook into a digital advertising empire, will continue to serve as an advisor to the company. She plans to focus on her girls leadership program through her foundation.", 'title_correlation': '100', 'timestamp': '2024-01-19T13:37:56.918825+00:00', 'num_of_tokens': 300}
# {'sentiment': 9.0, 'sentiment_token': 115, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Study finds clean data platform boosts performance of Meta’s machine learning@Auto Remarketing@META', 'data': 'PureCars, following its acquisition of AutoMiner, partnered with Meta for a study on dealership ads. Results showed a positive impact, with an 83% reduction in cost per lead, five times more leads, and 20 times greater reach in vehicle acquisition ads. Ads promoting new car sales saw doubled performance.', 'title_correlation': '100', 'timestamp': '2024-01-19T16:02:23.091016+00:00', 'num_of_tokens': 305}
# {'sentiment': 7.0, 'sentiment_token': 89, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'The Tech Trifecta: Why MSFT, META, & NVDA Could Rule in 2024@Barchartcom@META', 'data': 'The article discusses the option to switch the market flag in order to access targeted data from a specific country. The process involves opening the menu and selecting the desired market flag for customized information.', 'title_correlation': '100', 'timestamp': '2024-01-19T13:00:39.829532+00:00', 'num_of_tokens': 220}
# {'sentiment': 7.5, 'sentiment_token': 148, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'The Tech Trifecta: Why MSFT, META, & NVDA Could Rule in 2024@The Globe and Mail@META', 'data': 'The Nasdaq 100 reached a new high, driven by optimism from Taiwan Semiconductor Manufacturing Co. The "Magnificent Seven" tech stocks, including Alphabet, Amazon, Apple, Meta Platforms, Microsoft, Nvidia, and Tesla, contributed 60% to the S&P500 in 2023. Microsoft leads in AI development, Meta Platforms explores AI in products, and Nvidia dominates AI chips. Despite potential, investors must be cautious, as markets change and investments carry risks.', 'title_correlation': '100', 'timestamp': '2024-01-19T12:41:16.919471+00:00', 'num_of_tokens': 454}
# {'sentiment': 5.0, 'sentiment_token': 118, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Thinking about buying stock in Rail Vision Ltd, Meta Platforms, Airspan Networks, Roma Green Finance, or Spirit @KXAN@META', 'data': 'InvestorsObserver issues PriceWatch Alerts for Rail Vision Ltd, Meta Platforms, Airspan Networks, Roma Green Finance, and Spirit Airlines. The alerts, based on proprietary scoring, assess short-term technical, long-term technical, and fundamental factors to determine stock suitability for investment. Source: InvestorsObserver. [Link to original article unavailable.]', 'title_correlation': '80', 'timestamp': '2024-01-19T14:31:39.827869+00:00', 'num_of_tokens': 368}
# {'sentiment': 5.0, 'sentiment_token': 118, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Thinking about buying stock in Rail Vision Ltd, Meta Platforms, Airspan Networks, Roma Green Finance, or Spirit @MarketScreener@META', 'data': 'InvestorsObserver has issued PriceWatch Alerts for RVSN, META, MIMO, ROMA, and SAVE. The alerts, based on their proprietary scoring system, evaluate stocks using short-term technical, long-term technical, and fundamental factors to determine overall suitability for investment. The details and links can be found in the original article.', 'title_correlation': '40', 'timestamp': '2024-01-19T15:01:58.602204+00:00', 'num_of_tokens': 337}
# {'sentiment': 8.6, 'sentiment_token': 161, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'USD 419698 billion growth in Social Commerce Market from 2022 to 2027; The market is fragmented due to the @IT News Online@META', 'data': 'The social commerce market is projected to grow by USD 4196.98 billion between 2022 and 2027, at a CAGR of 31%. This growth is attributed to the fragmented market landscape, populated by major companies like Advance, Alibaba Group Holding Ltd., and Automattic Inc. Key factors driving this growth include the integration of online storefronts with social shopping apps, influential social media marketing, and an increased focus on personalized shopping experiences. The Asia Pacific region is expected to be a significant contributor to this growth.', 'title_correlation': '90', 'timestamp': '2024-01-19T21:49:32.296412+00:00', 'num_of_tokens': 550}
# {'sentiment': 6.0, 'sentiment_token': 142, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'Weekly Tech Wrap: Zuck Hails AGI As Next Big Thing, Galaxy AI Arrives, Starlink’s India Foray, More Top Technology News@abp LIVE@META', 'data': "Elon Musk's Starlink satellite Internet service is close to regulatory approval for entry into the Indian market. Mark Zuckerberg sees Artificial General Intelligence (AGI) as Meta's next major focus, emphasizing its role in AI advancements. Samsung unveils the Galaxy S24 series with a focus on AI features. Apple surpasses Samsung in global smartphone market share. Google announces significant layoffs in its advertising sales division, aligning with its shift towards AI and automation.", 'title_correlation': '85', 'timestamp': '2024-01-19T23:31:16.050632+00:00', 'num_of_tokens': 490}
# {'sentiment': 5.0, 'sentiment_token': 87, 'model_name': 'gpt-3.5-turbo', 'ds_id': 'What to Expect From Tech Earnings Season@The Information@META', 'data': 'Earnings season has resumed, with Netflix initiating the December-quarter reports for the tech sector. The article discusses the upcoming financial updates from various companies in the sector during this period.', 'title_correlation': '60', 'timestamp': '2024-01-19T23:04:27.291909+00:00', 'num_of_tokens': 212}
# {'sentiment': 8.5, 'sentiment_token': 197, 'model_name': 'gpt-3.5-turbo', 'ds_id': "What's Going On With Meta Platforms Stock Meta Platforms (NASDAQ:META)@Benzinga@META", 'data': "Meta Platforms, Inc. (META) CEO Mark Zuckerberg announced plans to acquire 350,000 H100 GPUs from Nvidia to advance the company's AI goals, aiming to build general intelligence and make it available to everyone. Meta is one of the top-trending stocks on WallStreetBets, and its Q4 2023 financial results are set for release on Feb. 1. The company is expected to announce earnings of $4.97 per share and quarterly revenue of $39.029 billion. Meta's average annual revenue growth over the past 5 years is 18.39%, with a forward P/E ratio of 22.42. The stock is currently trading at $380.25.", 'title_correlation': '100', 'timestamp': '2024-01-19T15:57:32.011711+00:00', 'num_of_tokens': 588}
# {'sentiment': 9.0, 'sentiment_token': 177, 'model_name': 'gpt-3.5-turbo', 'ds_id': "Why Meta Platforms Inc Is A Buy Acquirer's Multiple Stock Screener Analysis@The Acquirer's Multiple@META", 'data': "The article highlights Meta Platforms Inc (META) as an undervalued stock based on key fundamentals. With a market cap of $918.95 billion, Meta is the world's largest online social network, boasting 3.8 billion monthly active users. Advertising revenue, comprising over 90% of total revenue, drives the company's financial strength. The share price has risen by 174.9% in the past twelve months. Key stats include an operating earnings of $45.17 billion, an Acquirer's Multiple of 19.80, and a Piotroski F Score of 8.00.", 'title_correlation': '100', 'timestamp': '2024-01-19T06:29:23.761323+00:00', 'num_of_tokens': 519}
